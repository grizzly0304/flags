# %%
import requests
from bs4 import BeautifulSoup
import csv
from PIL import Image
from io import BytesIO
from collections import Counter

image_urls = []
flags = {}


# Funktion zum Herunterladen eines Bildes
def download_image(url):
    response = requests.get(url)
    response.raise_for_status()
    return Image.open(BytesIO(response.content))


# Funktion zur Zuordnung der Farben zu den 12 Farbkategorien
def get_color_category(rgb_color):
    color_categories = {
        "yellow": (255, 255, 0),
        "yellow-green": (154, 205, 50),
        "green": (0, 128, 0),
        "blue-green": (0, 255, 255),
        "blue": (0, 0, 255),
        "blue-violet": (138, 43, 226),
        "violet": (128, 0, 128),
        "red-violet": (255, 0, 255),
        "red": (255, 0, 0),
        "red-orange": (255, 69, 0),
        "orange": (255, 165, 0),
        "yellow-orange": (255, 215, 0),
    }

    min_dist = float("inf")
    closest_category = None

    for category, color in color_categories.items():
        dist = sum((comp1 - comp2) ** 2 for comp1, comp2 in zip(rgb_color, color))
        if dist < min_dist:
            min_dist = dist
            closest_category = category

    return closest_category


# Funktion zur Analyse der Farben eines Bildes
def analyze_image_colors(image):
    image = image.convert("RGB")
    pixels = list(image.getdata())
    color_counts = Counter(
        [
            get_color_category(pixel)
            for pixel in pixels
            if get_color_category(pixel) is not None
        ]
    )

    # Anzahl Pixel addieren und Farbanteile prozentual ausrechnen
    total_pixels = sum(color_counts.values())
    color_percentages = {
        color: round((count / total_pixels) * 100, 2)
        for color, count in color_counts.items()
    }

    for color in [
        "yellow",
        "yellow-green",
        "green",
        "blue-green",
        "blue",
        "blue-violet",
        "violet",
        "red-violet",
        "red",
        "red-orange",
        "orange",
        "yellow-orange",
    ]:
        if color not in color_percentages:
            color_percentages[color] = 0

    return color_percentages


# CSV-Datei erstellen und Header schreiben
with open("flags.csv", mode="w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow(
        [
            "Image URL",
            "Region",
            "State Name",
            "Flag Name",
            "Additional Info",
            "Year Added",
            "Year Removed",
            "yellow",
            "yellow-green",
            "green",
            "blue-green",
            "blue",
            "blue-violet",
            "violet",
            "red-violet",
            "red",
            "red-orange",
            "orange",
            "yellow-orange",
        ]
    )

# URL der Webseite
for year in range(1874, 2024):
    url = f"https://flaglog.com/{year}"
    flags[year] = []

    response = requests.get(url)
    response.raise_for_status()

    soup = BeautifulSoup(response.content, "html.parser")

    for section in soup.find_all("section"):
        if section.get("id") != "Other":
            region = section.get("id", "Unknown")
            for flag_div in section.find_all("div", class_="flag"):
                image_url = "https://flaglog.com/" + flag_div.find("img")["src"]
                state_name_div = flag_div.find("div", class_="flagname")
                state_name = str(state_name_div).replace('<div class="flagname">', "")
                state_name = state_name.split("<")[0]

                flag_name_div = flag_div.find("div", class_="type")
                flag_name = "N/A"
                if flag_name_div:
                    flag_name = flag_name_div.text.strip()
                    for i, char in enumerate(flag_name):
                        if char.isdigit():
                            flag_name = flag_name[:i].strip()
                            break

                comment_element = flag_div.find("span", class_="popnote")
                comment = comment_element.text.strip() if comment_element else "N/A"
                comment = comment.replace("&nbsp;", "")
                comment = "".join([i for i in comment if not i.isdigit()])

                year_added = "".join([i for i in image_url if i.isdigit()])
                if len(year_added) != 4:
                    year_added = "?"

                if image_url not in image_urls:
                    try:
                        image = download_image(image_url)
                        color_percentages = analyze_image_colors(image)
                    except Exception as e:
                        print(f"Fehler beim Verarbeiten des Bildes {image_url}: {e}")
                        color_percentages = {
                            color: 0
                            for color in [
                                "yellow",
                                "yellow-green",
                                "green",
                                "blue-green",
                                "blue",
                                "blue-violet",
                                "violet",
                                "red-violet",
                                "red",
                                "red-orange",
                                "orange",
                                "yellow-orange",
                            ]
                        }

                    with open(
                        "flags.csv", mode="a", newline="", encoding="utf-8"
                    ) as file:
                        writer = csv.writer(file)
                        writer.writerow(
                            [
                                image_url,
                                region,
                                state_name,
                                flag_name,
                                comment,
                                year_added,
                                "still in use",
                                color_percentages["yellow"],
                                color_percentages["yellow-green"],
                                color_percentages["green"],
                                color_percentages["blue-green"],
                                color_percentages["blue"],
                                color_percentages["blue-violet"],
                                color_percentages["violet"],
                                color_percentages["red-violet"],
                                color_percentages["red"],
                                color_percentages["red-orange"],
                                color_percentages["orange"],
                                color_percentages["yellow-orange"],
                            ]
                        )
                    image_urls.append(image_url)
                flags[year].append(image_url)

    if year == 1874:
        continue

    rip_flags = [flag for flag in flags[year - 1] if flag not in flags[year]]
    updated_rows = []

    with open("flags.csv", mode="r", newline="", encoding="utf-8") as read_file:
        reader = csv.reader(read_file)
        existing_rows = list(reader)

    for row in existing_rows:
        if row[0] in rip_flags:
            row[6] = year
        updated_rows.append(row)

    with open("flags.csv", mode="w", newline="", encoding="utf-8") as write_file:
        writer = csv.writer(write_file)
        writer.writerows(updated_rows)

print("Daten wurden erfolgreich in 'flags.csv' gespeichert.")
# Out:
# /Users/grizzly0304/Library/Python/3.9/lib/python/site-packages/PIL/Image.py:1000: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Fehler beim Verarbeiten des Bildes https://flaglog.com/img/france1940-free.png: 404 Client Error: Not Found for url: https://flaglog.com/img/france1940-free.png
# Daten wurden erfolgreich in 'flags.csv' gespeichert.

# %%
import os
import requests
from bs4 import BeautifulSoup

# Funktion zum Herunterladen eines Bildes
def download_image(url, save_path):
    response = requests.get(url)
    response.raise_for_status()
    with open(save_path, 'wb') as f:
        f.write(response.content)

# Ordner "flags" erstellen, falls er nicht existiert
os.makedirs('flags', exist_ok=True)

# Liste der Jahre, von denen die Flaggenbilder heruntergeladen werden sollen
years = range(1874, 2024)

# Set zur Überprüfung doppelter Bild-URLs
downloaded_images = set()

for year in years:
    url = f"https://flaglog.com/{year}"

    # HTTP-Anfrage an die Webseite senden
    response = requests.get(url)
    response.raise_for_status()

    # Inhalt der Webseite mit BeautifulSoup parsen
    soup = BeautifulSoup(response.content, 'html.parser')

    for section in soup.find_all('section'):
        if section.get('id') != 'Other':
            for flag_div in section.find_all('div', class_='flag'):
                image_url = 'https://flaglog.com/' + flag_div.find('img')['src']
                
                # Überprüfen, ob das Bild bereits heruntergeladen wurde
                if image_url not in downloaded_images:
                    image_name = image_url.split('/')[-1]
                    save_path = os.path.join('flags', image_name)
                    
                    try:
                        download_image(image_url, save_path)
                        print(f"Bild heruntergeladen und gespeichert: {save_path}")
                        downloaded_images.add(image_url)
                    except Exception as e:
                        print(f"Fehler beim Herunterladen des Bildes {image_url}: {e}")

print("Alle Bilder wurden erfolgreich heruntergeladen und im Ordner 'flags' gespeichert.")
# Out:
# Bild heruntergeladen und gespeichert: flags/turkey1844.png
# Bild heruntergeladen und gespeichert: flags/tunisia1831.png
# Bild heruntergeladen und gespeichert: flags/egypt1841.png
# Bild heruntergeladen und gespeichert: flags/jebelshammar1836.png
# Bild heruntergeladen und gespeichert: flags/nejd1750.png
# Bild heruntergeladen und gespeichert: flags/tripoli1727.png
# Bild heruntergeladen und gespeichert: flags/morocco1667.png
# Bild heruntergeladen und gespeichert: flags/muscat1649.png
# Bild heruntergeladen und gespeichert: flags/qasimi1820.png
# Bild heruntergeladen und gespeichert: flags/madagascar1817.png
# Bild heruntergeladen und gespeichert: flags/persia1797.png
# Bild heruntergeladen und gespeichert: flags/lebanon1861.png
# Bild heruntergeladen und gespeichert: flags/futajallon1725.png
# Bild heruntergeladen und gespeichert: flags/sokoto1804.png
# Bild heruntergeladen und gespeichert: flags/orange1856.png
# Bild heruntergeladen und gespeichert: flags/transvaal1874.png
# Bild heruntergeladen und gespeichert: flags/liberia1847.png
# Bild heruntergeladen und gespeichert: flags/france1794.png
# Bild heruntergeladen und gespeichert: flags/italy1861.png
# Bild heruntergeladen und gespeichert: flags/italy1861-state.png
# Bild heruntergeladen und gespeichert: flags/belgium1831.png
# Bild heruntergeladen und gespeichert: flags/austria1804.png
# Bild heruntergeladen und gespeichert: flags/austria1804-civil.png
# Bild heruntergeladen und gespeichert: flags/netherlands1596.png
# Bild heruntergeladen und gespeichert: flags/luxembourg1845.png
# Bild heruntergeladen und gespeichert: flags/germany1867.png
# Bild heruntergeladen und gespeichert: flags/spain1785.png
# Bild heruntergeladen und gespeichert: flags/andorra1866.png
# Bild heruntergeladen und gespeichert: flags/switzerland1848.png
# Bild heruntergeladen und gespeichert: flags/denmark1748.png
# Bild heruntergeladen und gespeichert: flags/denmark1856-state.png
# Bild heruntergeladen und gespeichert: flags/norway1844.png
# Bild heruntergeladen und gespeichert: flags/norway1844-state.png
# Bild heruntergeladen und gespeichert: flags/sweden1844.png
# Bild heruntergeladen und gespeichert: flags/sweden1844-state.png
# Bild heruntergeladen und gespeichert: flags/greece1822-land.png
# Bild heruntergeladen und gespeichert: flags/greece1822.png
# Bild heruntergeladen und gespeichert: flags/samos1832.png
# Bild heruntergeladen und gespeichert: flags/unitedkingdom1801.png
# Bild heruntergeladen und gespeichert: flags/england1277.png
# Bild heruntergeladen und gespeichert: flags/scotland1542.png
# Bild heruntergeladen und gespeichert: flags/jersey1841.png
# Bild heruntergeladen und gespeichert: flags/sanmarino1862.png
# Bild heruntergeladen und gespeichert: flags/liechtenstein1806.png
# Bild heruntergeladen und gespeichert: flags/portugal1830.png
# Bild heruntergeladen und gespeichert: flags/malta1798-traditional.png
# Bild heruntergeladen und gespeichert: flags/monaco1814.png
# Bild heruntergeladen und gespeichert: flags/catalonia1810.png
# Bild heruntergeladen und gespeichert: flags/cornwall1838.png
# Bild heruntergeladen und gespeichert: flags/corsica1755.png
# Bild heruntergeladen und gespeichert: flags/wales1807.png
# Bild heruntergeladen und gespeichert: flags/iceland1870.png
# Bild heruntergeladen und gespeichert: flags/ireland1798.png
# Bild heruntergeladen und gespeichert: flags/flanders1297.png
# Bild heruntergeladen und gespeichert: flags/heligoland1814.png
# Bild heruntergeladen und gespeichert: flags/russia1703-standard.png
# Bild heruntergeladen und gespeichert: flags/russia1858.png
# Bild heruntergeladen und gespeichert: flags/russia1705.png
# Bild heruntergeladen und gespeichert: flags/carniola1848.png
# Bild heruntergeladen und gespeichert: flags/slovakia1848.png
# Bild heruntergeladen und gespeichert: flags/croatia1867.png
# Bild heruntergeladen und gespeichert: flags/serbia1835.png
# Bild heruntergeladen und gespeichert: flags/serbia1838.png
# Bild heruntergeladen und gespeichert: flags/hungary1867.png
# Bild heruntergeladen und gespeichert: flags/romania1866.png
# Bild heruntergeladen und gespeichert: flags/ukraine1848.png
# Bild heruntergeladen und gespeichert: flags/bohemia1848.png
# Bild heruntergeladen und gespeichert: flags/montenegro1860.png
# Bild heruntergeladen und gespeichert: flags/poland1795.png
# Bild heruntergeladen und gespeichert: flags/bulgaria1862.png
# Bild heruntergeladen und gespeichert: flags/hyderabad1724.png
# Bild heruntergeladen und gespeichert: flags/kashmir1846.png
# Bild heruntergeladen und gespeichert: flags/nepal1856.png
# Bild heruntergeladen und gespeichert: flags/jhabua1607.png
# Bild heruntergeladen und gespeichert: flags/dewas-unknown.png
# Bild heruntergeladen und gespeichert: flags/kota1817.png
# Bild heruntergeladen und gespeichert: flags/maldives1796.png
# Bild heruntergeladen und gespeichert: flags/kishangarh19th.png
# Bild heruntergeladen und gespeichert: flags/sailana1819.png
# Bild heruntergeladen und gespeichert: flags/ajaigarh-unknown.png
# Bild heruntergeladen und gespeichert: flags/mewar1826.png
# Bild heruntergeladen und gespeichert: flags/porbandar1809.png
# Bild heruntergeladen und gespeichert: flags/maratha1674.png
# Bild heruntergeladen und gespeichert: flags/dhar1858.png
# Bild heruntergeladen und gespeichert: flags/jaora1865.png
# Bild heruntergeladen und gespeichert: flags/jaipur1818.png
# Bild heruntergeladen und gespeichert: flags/alwar1775.png
# Bild heruntergeladen und gespeichert: flags/idar1741.png
# Bild heruntergeladen und gespeichert: flags/sirohi-unknown.png
# Bild heruntergeladen und gespeichert: flags/jodhpur1818.png
# Bild heruntergeladen und gespeichert: flags/gwalior1726.png
# Bild heruntergeladen und gespeichert: flags/jaisalmer19th.png
# Bild heruntergeladen und gespeichert: flags/bikaner1818.png
# Bild heruntergeladen und gespeichert: flags/banswara1581.png
# Bild heruntergeladen und gespeichert: flags/dholpur1780.png
# Bild heruntergeladen und gespeichert: flags/rajpipla-unknown.png
# Bild heruntergeladen und gespeichert: flags/rajpipla19th-national.png
# Bild heruntergeladen und gespeichert: flags/indore1818.png
# Bild heruntergeladen und gespeichert: flags/kalat1680.png
# Bild heruntergeladen und gespeichert: flags/travancore19th.png
# Bild heruntergeladen und gespeichert: flags/manipur1825.png
# Bild heruntergeladen und gespeichert: flags/rajgarh-unknown.png
# Bild heruntergeladen und gespeichert: flags/sitamau-unknown.png
# Bild heruntergeladen und gespeichert: flags/bundi1579.png
# Bild heruntergeladen und gespeichert: flags/alirajpur-unknown.png
# Bild heruntergeladen und gespeichert: flags/khairpur1860.png
# Bild heruntergeladen und gespeichert: flags/japan1854.png
# Bild heruntergeladen und gespeichert: flags/china1862.png
# Bild heruntergeladen und gespeichert: flags/cambodia1863.png
# Bild heruntergeladen und gespeichert: flags/siam1839.png
# Bild heruntergeladen und gespeichert: flags/luangprabang1707.png
# Bild heruntergeladen und gespeichert: flags/champassak1713.png
# Bild heruntergeladen und gespeichert: flags/burma1835.png
# Bild heruntergeladen und gespeichert: flags/kelantan1764.png
# Bild heruntergeladen und gespeichert: flags/jambi1700.png
# Bild heruntergeladen und gespeichert: flags/jambi1800-noble.png
# Bild heruntergeladen und gespeichert: flags/jambi1800-merchant.png
# Bild heruntergeladen und gespeichert: flags/pahang1853.png
# Bild heruntergeladen und gespeichert: flags/brunei1473.png
# Bild heruntergeladen und gespeichert: flags/sarawak1870.png
# Bild heruntergeladen und gespeichert: flags/selangor1859.png
# Bild heruntergeladen und gespeichert: flags/perlis1870.png
# Bild heruntergeladen und gespeichert: flags/johor1871.png
# Bild heruntergeladen und gespeichert: flags/johor1871-merchant.png
# Bild heruntergeladen und gespeichert: flags/kedah1821.png
# Bild heruntergeladen und gespeichert: flags/kashgaria1873.png
# Bild heruntergeladen und gespeichert: flags/sulu1850.png
# Bild heruntergeladen und gespeichert: flags/samoa1873a.png
# Bild heruntergeladen und gespeichert: flags/tonga1866.png
# Bild heruntergeladen und gespeichert: flags/uvea1858.png
# Bild heruntergeladen und gespeichert: flags/rimatara1856.png
# Bild heruntergeladen und gespeichert: flags/tahiti1842.png
# Bild heruntergeladen und gespeichert: flags/rarotonga1858.png
# Bild heruntergeladen und gespeichert: flags/mangareva1832.png
# Bild heruntergeladen und gespeichert: flags/rurutu1858.png
# Bild heruntergeladen und gespeichert: flags/huahine1847.png
# Bild heruntergeladen und gespeichert: flags/raiatea1847.png
# Bild heruntergeladen und gespeichert: flags/borabora1847.png
# Bild heruntergeladen und gespeichert: flags/tahuata1837.png
# Bild heruntergeladen und gespeichert: flags/hawaii1845.png
# Bild heruntergeladen und gespeichert: flags/australia1831.png
# Bild heruntergeladen und gespeichert: flags/newzealand1869.png
# Bild heruntergeladen und gespeichert: flags/newzealand1834.png
# Bild heruntergeladen und gespeichert: flags/unitedstates1867.png
# Bild heruntergeladen und gespeichert: flags/canada1873.png
# Bild heruntergeladen und gespeichert: flags/texas1839.png
# Bild heruntergeladen und gespeichert: flags/newfoundland1860.png
# Bild heruntergeladen und gespeichert: flags/metis1983.png
# Bild heruntergeladen und gespeichert: flags/brazil1853.png
# Bild heruntergeladen und gespeichert: flags/mexico1823.png
# Bild heruntergeladen und gespeichert: flags/peru1825-state.png
# Bild heruntergeladen und gespeichert: flags/peru1822.png
# Bild heruntergeladen und gespeichert: flags/guatemala1871.png
# Bild heruntergeladen und gespeichert: flags/argentina1818.png
# Bild heruntergeladen und gespeichert: flags/honduras1866-civil.png
# Bild heruntergeladen und gespeichert: flags/centralamerica1838.png
# Bild heruntergeladen und gespeichert: flags/paraguay1842.png
# Bild heruntergeladen und gespeichert: flags/paraguay1842-reverse.png
# Bild heruntergeladen und gespeichert: flags/costarica1848.png
# Bild heruntergeladen und gespeichert: flags/costarica1848-state.png
# Bild heruntergeladen und gespeichert: flags/cuba1869.png
# Bild heruntergeladen und gespeichert: flags/elsalvador1873.png
# Bild heruntergeladen und gespeichert: flags/uruguay1830.png
# Bild heruntergeladen und gespeichert: flags/haiti1810-state.png
# Bild heruntergeladen und gespeichert: flags/dominican1863.png
# Bild heruntergeladen und gespeichert: flags/puertorico1868.png
# Bild heruntergeladen und gespeichert: flags/chile1817.png
# Bild heruntergeladen und gespeichert: flags/bolivia1851.png
# Bild heruntergeladen und gespeichert: flags/bolivia1851-civil.png
# Bild heruntergeladen und gespeichert: flags/venezuela1863-state.png
# Bild heruntergeladen und gespeichert: flags/venezuela1863.png
# Bild heruntergeladen und gespeichert: flags/colombia1861.png
# Bild heruntergeladen und gespeichert: flags/ecuador1860.png
# Bild heruntergeladen und gespeichert: flags/transvaal1858.png
# Bild heruntergeladen und gespeichert: flags/baroda1875.png
# Bild heruntergeladen und gespeichert: flags/samoa1875.png
# Bild heruntergeladen und gespeichert: flags/bulgaria1877.png
# Bild heruntergeladen und gespeichert: flags/sailana1877.png
# Bild heruntergeladen und gespeichert: flags/jaipur1877.png
# Bild heruntergeladen und gespeichert: flags/jodhpur1877.png
# Bild heruntergeladen und gespeichert: flags/nabha-unknown.png
# Bild heruntergeladen und gespeichert: flags/wankaner-unknown.png
# Bild heruntergeladen und gespeichert: flags/chhatarpur-unknown.png
# Bild heruntergeladen und gespeichert: flags/cambay1877.png
# Bild heruntergeladen und gespeichert: flags/bhavnagar1877.png
# Bild heruntergeladen und gespeichert: flags/tonk-unknown.png
# Bild heruntergeladen und gespeichert: flags/garhwal-unknown.png
# Bild heruntergeladen und gespeichert: flags/suket-unknown.png
# Bild heruntergeladen und gespeichert: flags/pratapgarh1877.png
# Bild heruntergeladen und gespeichert: flags/barwani-unknown.png
# Bild heruntergeladen und gespeichert: flags/faridkot-unknown.png
# Bild heruntergeladen und gespeichert: flags/baoni-unknown.png
# Bild heruntergeladen und gespeichert: flags/mandi-unknown.png
# Bild heruntergeladen und gespeichert: flags/kishangarh-unknown.png
# Bild heruntergeladen und gespeichert: flags/bhopal1877.png
# Bild heruntergeladen und gespeichert: flags/bilaspur-unknown.png
# Bild heruntergeladen und gespeichert: flags/sikkim1877.png
# Bild heruntergeladen und gespeichert: flags/unitedstates1877.png
# Bild heruntergeladen und gespeichert: flags/elsalvador1877.png
# Bild heruntergeladen und gespeichert: flags/serbia1878.png
# Bild heruntergeladen und gespeichert: flags/bulgaria1879.png
# Bild heruntergeladen und gespeichert: flags/bosnia1878a.png
# Bild heruntergeladen und gespeichert: flags/montenegro1878.png
# Bild heruntergeladen und gespeichert: flags/albania1878.png
# Bild heruntergeladen und gespeichert: flags/perak1879.png
# Bild heruntergeladen und gespeichert: flags/samoa1879.png
# Bild heruntergeladen und gespeichert: flags/montenegro1880a.png
# Bild heruntergeladen und gespeichert: flags/raiatea1880.png
# Bild heruntergeladen und gespeichert: flags/mexico1880.png
# Bild heruntergeladen und gespeichert: flags/madagascar1881.png
# Bild heruntergeladen und gespeichert: flags/monaco1881.png
# Bild heruntergeladen und gespeichert: flags/monaco1881-state.png
# Bild heruntergeladen und gespeichert: flags/montenegro1881.png
# Bild heruntergeladen und gespeichert: flags/mysore1881.png
# Bild heruntergeladen und gespeichert: flags/egypt1882.png
# Bild heruntergeladen und gespeichert: flags/serbia1882.png
# Bild heruntergeladen und gespeichert: flags/korea1882.png
# Bild heruntergeladen und gespeichert: flags/estonia1881.png
# Bild heruntergeladen und gespeichert: flags/abemama1884.png
# Bild heruntergeladen und gespeichert: flags/acadia1884.png
# Bild heruntergeladen und gespeichert: flags/congofreestate1879.png
# Bild heruntergeladen und gespeichert: flags/bahawalpur1885.png
# Bild heruntergeladen und gespeichert: flags/pahang1887.png
# Bild heruntergeladen und gespeichert: flags/samoa1887.png
# Bild heruntergeladen und gespeichert: flags/china1888.png
# Bild heruntergeladen und gespeichert: flags/wallisfutuna1887.png
# Bild heruntergeladen und gespeichert: flags/rarotonga1888.png
# Bild heruntergeladen und gespeichert: flags/bolivia1888.png
# Bild heruntergeladen und gespeichert: flags/switzerland1889.png
# Bild heruntergeladen und gespeichert: flags/rurutu1889.png
# Bild heruntergeladen und gespeichert: flags/abemama1889.png
# Bild heruntergeladen und gespeichert: flags/brazil1889.png
# Bild heruntergeladen und gespeichert: flags/swaziland1890.png
# Bild heruntergeladen und gespeichert: flags/bharatpur1890.png
# Bild heruntergeladen und gespeichert: flags/kochin1890.png
# Bild heruntergeladen und gespeichert: flags/rewa1890.png
# Bild heruntergeladen und gespeichert: flags/karauli1890.png
# Bild heruntergeladen und gespeichert: flags/rampur1890.png
# Bild heruntergeladen und gespeichert: flags/unitedstates1890.png
# Bild heruntergeladen und gespeichert: flags/galicia1891.png
# Bild heruntergeladen und gespeichert: flags/rimatara1891.png
# Bild heruntergeladen und gespeichert: flags/unitedstates1891.png
# Bild heruntergeladen und gespeichert: flags/denmark1893.png
# Bild heruntergeladen und gespeichert: flags/kutch1893.png
# Bild heruntergeladen und gespeichert: flags/coochbehar-unknown.png
# Bild heruntergeladen und gespeichert: flags/laos1893.png
# Bild heruntergeladen und gespeichert: flags/cookislands1893.png
# Bild heruntergeladen und gespeichert: flags/basquecountry1894.png
# Bild heruntergeladen und gespeichert: flags/jaora1895.png
# Bild heruntergeladen und gespeichert: flags/negerisembilan1895.png
# Bild heruntergeladen und gespeichert: flags/puertorico1895.png
# Bild heruntergeladen und gespeichert: flags/persia1896.png
# Bild heruntergeladen und gespeichert: flags/futajallon1896.png
# Bild heruntergeladen und gespeichert: flags/malaya1896.png
# Bild heruntergeladen und gespeichert: flags/unitedstates1896.png
# Bild heruntergeladen und gespeichert: flags/nicaragua1896.png
# Bild heruntergeladen und gespeichert: flags/dominican1896.png
# Bild heruntergeladen und gespeichert: flags/ethiopia1897.png
# Bild heruntergeladen und gespeichert: flags/zanzibar1861.png
# Bild heruntergeladen und gespeichert: flags/sweden1897-state.png
# Bild heruntergeladen und gespeichert: flags/iceland1897.png
# Bild heruntergeladen und gespeichert: flags/philippines1897.png
# Bild heruntergeladen und gespeichert: flags/crete1898.png
# Bild heruntergeladen und gespeichert: flags/philippines1898.png
# Bild heruntergeladen und gespeichert: flags/norway1821.png
# Bild heruntergeladen und gespeichert: flags/norway1821-state.png
# Bild heruntergeladen und gespeichert: flags/moro1899.png
# Bild heruntergeladen und gespeichert: flags/charkhari1900.png
# Bild heruntergeladen und gespeichert: flags/kapurthala-unknown.png
# Bild heruntergeladen und gespeichert: flags/orchha-unknown.png
# Bild heruntergeladen und gespeichert: flags/dungarpur-unknown.png
# Bild heruntergeladen und gespeichert: flags/ecuador1900-state.png
# Bild heruntergeladen und gespeichert: flags/afghanistan1901.png
# Bild heruntergeladen und gespeichert: flags/australia1901.png
# Bild heruntergeladen und gespeichert: flags/nejd1902.png
# Bild heruntergeladen und gespeichert: flags/quebec1902.png
# Bild heruntergeladen und gespeichert: flags/maldives1903.png
# Bild heruntergeladen und gespeichert: flags/australia1903.png
# Bild heruntergeladen und gespeichert: flags/quebec1903.png
# Bild heruntergeladen und gespeichert: flags/panama1903.png
# Bild heruntergeladen und gespeichert: flags/newfoundland1904.png
# Bild heruntergeladen und gespeichert: flags/sweden1663.png
# Bild heruntergeladen und gespeichert: flags/sweden1905-state.png
# Bild heruntergeladen und gespeichert: flags/montenegro1905.png
# Bild heruntergeladen und gespeichert: flags/venezuela1905-state.png
# Bild heruntergeladen und gespeichert: flags/venezuela1905.png
# Bild heruntergeladen und gespeichert: flags/india1906.png
# Bild heruntergeladen und gespeichert: flags/muslimleague1906.png
# Bild heruntergeladen und gespeichert: flags/brunei1906.png
# Bild heruntergeladen und gespeichert: flags/costarica1906.png
# Bild heruntergeladen und gespeichert: flags/costarica1906-state.png
# Bild heruntergeladen und gespeichert: flags/persia1907.png
# Bild heruntergeladen und gespeichert: flags/persia1907-civil.png
# Bild heruntergeladen und gespeichert: flags/manipur1907.png
# Bild heruntergeladen und gespeichert: flags/canada1907.png
# Bild heruntergeladen und gespeichert: flags/bosnia1908.png
# Bild heruntergeladen und gespeichert: flags/gwalior1908.png
# Bild heruntergeladen und gespeichert: flags/porbandar1908.png
# Bild heruntergeladen und gespeichert: flags/australia1908.png
# Bild heruntergeladen und gespeichert: flags/unitedstates1908.png
# Bild heruntergeladen und gespeichert: flags/nicaragua1908.png
# Bild heruntergeladen und gespeichert: flags/southafrica1910.png
# Bild heruntergeladen und gespeichert: flags/bahrain1910.png
# Bild heruntergeladen und gespeichert: flags/portugal1910.png
# Bild heruntergeladen und gespeichert: flags/benares1911.png
# Bild heruntergeladen und gespeichert: flags/dhrangadhra1911.png
# Bild heruntergeladen und gespeichert: flags/mongolia1911.png
# Bild heruntergeladen und gespeichert: flags/california1911.png
# Bild heruntergeladen und gespeichert: flags/southafrica1912.png
# Bild heruntergeladen und gespeichert: flags/albania1912.png
# Bild heruntergeladen und gespeichert: flags/jhalawar1912.png
# Bild heruntergeladen und gespeichert: flags/china1912.png
# Bild heruntergeladen und gespeichert: flags/terengganu1912.png
# Bild heruntergeladen und gespeichert: flags/kedah1912.png
# Bild heruntergeladen und gespeichert: flags/kedah1912-civil.png
# Bild heruntergeladen und gespeichert: flags/kelantan1912.png
# Bild heruntergeladen und gespeichert: flags/unitedstates1912.png
# Bild heruntergeladen und gespeichert: flags/elsalvador1912.png
# Bild heruntergeladen und gespeichert: flags/elsalvador1912-national.png
# Bild heruntergeladen und gespeichert: flags/elsalvador1912-civil.png
# Bild heruntergeladen und gespeichert: flags/wallonia1913.png
# Bild heruntergeladen und gespeichert: flags/kuwait1914.png
# Bild heruntergeladen und gespeichert: flags/russia1914-civil.png
# Bild heruntergeladen und gespeichert: flags/morocco1915.png
# Bild heruntergeladen und gespeichert: flags/iceland1915.png
# Bild heruntergeladen und gespeichert: flags/iceland1915-state.png
# Bild heruntergeladen und gespeichert: flags/kandy1798.png
# Bild heruntergeladen und gespeichert: flags/china1915.png
# Bild heruntergeladen und gespeichert: flags/hejaz1916.png
# Bild heruntergeladen und gespeichert: flags/qatar1916.png
# Bild heruntergeladen und gespeichert: flags/ireland1916.png
# Bild heruntergeladen und gespeichert: flags/poland1916.png
# Bild heruntergeladen und gespeichert: flags/siam1916.png
# Bild heruntergeladen und gespeichert: flags/siam1916-civil.png
# Bild heruntergeladen und gespeichert: flags/mexico1916.png
# Bild heruntergeladen und gespeichert: flags/hashemite1917.png
# Bild heruntergeladen und gespeichert: flags/asir1917.png
# Bild heruntergeladen und gespeichert: flags/finland1917.png
# Bild heruntergeladen und gespeichert: flags/finland1917-civil.png
# Bild heruntergeladen und gespeichert: flags/byelorussia1917.png
# Bild heruntergeladen und gespeichert: flags/crimea1917.png
# Bild heruntergeladen und gespeichert: flags/latvia1917.png
# Bild heruntergeladen und gespeichert: flags/moldavia1917.png
# Bild heruntergeladen und gespeichert: flags/lithuania1917.png
# Bild heruntergeladen und gespeichert: flags/siberia1917.png
# Bild heruntergeladen und gespeichert: flags/mountain1917.png
# Bild heruntergeladen und gespeichert: flags/alash1917.png
# Bild heruntergeladen und gespeichert: flags/bukhara1917.png
# Bild heruntergeladen und gespeichert: flags/khiva1917.png
# Bild heruntergeladen und gespeichert: flags/turkestan1917.png
# Bild heruntergeladen und gespeichert: flags/thailand1917.png
# Bild heruntergeladen und gespeichert: flags/guam1917.png
# Bild heruntergeladen und gespeichert: flags/yemen1918.png
# Bild heruntergeladen und gespeichert: flags/assyria1918.png
# Bild heruntergeladen und gespeichert: flags/austria1918.png
# Bild heruntergeladen und gespeichert: flags/finland1918.png
# Bild heruntergeladen und gespeichert: flags/finland1918-state.png
# Bild heruntergeladen und gespeichert: flags/catalonia1918-estelada.png
# Bild heruntergeladen und gespeichert: flags/russia1918.png
# Bild heruntergeladen und gespeichert: flags/latvia1918-ssr.png
# Bild heruntergeladen und gespeichert: flags/estonia1918-ssr.png
# Bild heruntergeladen und gespeichert: flags/lithuania1918-ssr.png
# Bild heruntergeladen und gespeichert: flags/yugoslavia1918.png
# Bild heruntergeladen und gespeichert: flags/czechoslovakia1918.png
# Bild heruntergeladen und gespeichert: flags/hungary1918.png
# Bild heruntergeladen und gespeichert: flags/don1918.png
# Bild heruntergeladen und gespeichert: flags/armenia1918.png
# Bild heruntergeladen und gespeichert: flags/azerbaijan1918.png
# Bild heruntergeladen und gespeichert: flags/lithuania1918.png
# Bild heruntergeladen und gespeichert: flags/georgia1918.png
# Bild heruntergeladen und gespeichert: flags/ukraine1918.png
# Bild heruntergeladen und gespeichert: flags/karelia1918.png
# Bild heruntergeladen und gespeichert: flags/kuban1918.png
# Bild heruntergeladen und gespeichert: flags/bashkiria1918.png
# Bild heruntergeladen und gespeichert: flags/mountain1918.png
# Bild heruntergeladen und gespeichert: flags/oirat1918.png
# Bild heruntergeladen und gespeichert: flags/uriankhai1918.png
# Bild heruntergeladen und gespeichert: flags/kurdistan1919.png
# Bild heruntergeladen und gespeichert: flags/austria1919-state.png
# Bild heruntergeladen und gespeichert: flags/germany1848.png
# Bild heruntergeladen und gespeichert: flags/faroeislands1919.png
# Bild heruntergeladen und gespeichert: flags/ukraine1919.png
# Bild heruntergeladen und gespeichert: flags/hungary1919.png
# Bild heruntergeladen und gespeichert: flags/ingria1919.png
# Bild heruntergeladen und gespeichert: flags/northcaucasus1919.png
# Bild heruntergeladen und gespeichert: flags/afghanistan1919.png
# Bild heruntergeladen und gespeichert: flags/korea1919.png
# Bild heruntergeladen und gespeichert: flags/hashemite1920.png
# Bild heruntergeladen und gespeichert: flags/syria1920.png
# Bild heruntergeladen und gespeichert: flags/israel1897.png
# Bild heruntergeladen und gespeichert: flags/lebanon1920.png
# Bild heruntergeladen und gespeichert: flags/finland1920-state.png
# Bild heruntergeladen und gespeichert: flags/saar1920.png
# Bild heruntergeladen und gespeichert: flags/byelorussia1920.png
# Bild heruntergeladen und gespeichert: flags/armenia1920.png
# Bild heruntergeladen und gespeichert: flags/azerbaijan1920.png
# Bild heruntergeladen und gespeichert: flags/khorezm1920.png
# Bild heruntergeladen und gespeichert: flags/bukhara1920.png
# Bild heruntergeladen und gespeichert: flags/fareast1920.png
# Bild heruntergeladen und gespeichert: flags/czechoslovakia1920.png
# Bild heruntergeladen und gespeichert: flags/albania1920.png
# Bild heruntergeladen und gespeichert: flags/danzig1920.png
# Bild heruntergeladen und gespeichert: flags/karelia1920.png
# Bild heruntergeladen und gespeichert: flags/tibet1920.png
# Bild heruntergeladen und gespeichert: flags/philippines1920.png
# Bild heruntergeladen und gespeichert: flags/annam1920.png
# Bild heruntergeladen und gespeichert: flags/liechtenstein1921.png
# Bild heruntergeladen und gespeichert: flags/georgia1921a.png
# Bild heruntergeladen und gespeichert: flags/azerbaijan1921.png
# Bild heruntergeladen und gespeichert: flags/turkestan1921.png
# Bild heruntergeladen und gespeichert: flags/india1921.png
# Bild heruntergeladen und gespeichert: flags/china1921-nationalist.png
# Bild heruntergeladen und gespeichert: flags/tannutuva1921.png
# Bild heruntergeladen und gespeichert: flags/usvirgin1921.png
# Bild heruntergeladen und gespeichert: flags/syria1922.png
# Bild heruntergeladen und gespeichert: flags/druze1922.png
# Bild heruntergeladen und gespeichert: flags/aland1922.png
# Bild heruntergeladen und gespeichert: flags/transcaucasia1922.png
# Bild heruntergeladen und gespeichert: flags/khorezm1922.png
# Bild heruntergeladen und gespeichert: flags/lithuania1922-state.png
# Bild heruntergeladen und gespeichert: flags/jaipur1922.png
# Bild heruntergeladen und gespeichert: flags/indonesia1922a.png
# Bild heruntergeladen und gespeichert: flags/canada1922.png
# Bild heruntergeladen und gespeichert: flags/egypt1923.png
# Bild heruntergeladen und gespeichert: flags/brittany1923.png
# Bild heruntergeladen und gespeichert: flags/ussr1923.png
# Bild heruntergeladen und gespeichert: flags/khorezm1923.png
# Bild heruntergeladen und gespeichert: flags/bukhara1923.png
# Bild heruntergeladen und gespeichert: flags/kelantan1923.png
# Bild heruntergeladen und gespeichert: flags/mikmaq1923.png
# Bild heruntergeladen und gespeichert: flags/iraq1924.png
# Bild heruntergeladen und gespeichert: flags/alawite1922.png
# Bild heruntergeladen und gespeichert: flags/indore1924.png
# Bild heruntergeladen und gespeichert: flags/janjira1924.png
# Bild heruntergeladen und gespeichert: flags/mongolia1924.png
# Bild heruntergeladen und gespeichert: flags/dominican1924.png
# Bild heruntergeladen und gespeichert: flags/bolivia1924.png
# Bild heruntergeladen und gespeichert: flags/anc1925.png
# Bild heruntergeladen und gespeichert: flags/tibet1925.png
# Bild heruntergeladen und gespeichert: flags/tannutuva1926.png
# Bild heruntergeladen und gespeichert: flags/yemen1927.png
# Bild heruntergeladen und gespeichert: flags/kurdistan1927.png
# Bild heruntergeladen und gespeichert: flags/alaska1927.png
# Bild heruntergeladen und gespeichert: flags/southafrica1928.png
# Bild heruntergeladen und gespeichert: flags/algeria1928.png
# Bild heruntergeladen und gespeichert: flags/transjordan1928.png
# Bild heruntergeladen und gespeichert: flags/poland1928-state.png
# Bild heruntergeladen und gespeichert: flags/afghanistan1928.png
# Bild heruntergeladen und gespeichert: flags/panna1928.png
# Bild heruntergeladen und gespeichert: flags/indonesia1928.png
# Bild heruntergeladen und gespeichert: flags/vatican1929.png
# Bild heruntergeladen und gespeichert: flags/isleofman1929.png
# Bild heruntergeladen und gespeichert: flags/albania1929-civil.png
# Bild heruntergeladen und gespeichert: flags/albania1929.png
# Bild heruntergeladen und gespeichert: flags/afghanistan1929a.png
# Bild heruntergeladen und gespeichert: flags/syria1930.png
# Bild heruntergeladen und gespeichert: flags/nepal1930.png
# Bild heruntergeladen und gespeichert: flags/mongolia1930.png
# Bild heruntergeladen und gespeichert: flags/tannutuva1930a.png
# Bild heruntergeladen und gespeichert: flags/venezuela1930-state.png
# Bild heruntergeladen und gespeichert: flags/venezuela1930.png
# Bild heruntergeladen und gespeichert: flags/trucial1931.png
# Bild heruntergeladen und gespeichert: flags/spain1931.png
# Bild heruntergeladen und gespeichert: flags/india1931.png
# Bild heruntergeladen und gespeichert: flags/afghanistan1931.png
# Bild heruntergeladen und gespeichert: flags/alwar1931.png
# Bild heruntergeladen und gespeichert: flags/tripura1931.png
# Bild heruntergeladen und gespeichert: flags/ethiopia1932.png
# Bild heruntergeladen und gespeichert: flags/kurdistan1932.png
# Bild heruntergeladen und gespeichert: flags/maldives1932.png
# Bild heruntergeladen und gespeichert: flags/manchukuo1932.png
# Bild heruntergeladen und gespeichert: flags/persia1933.png
# Bild heruntergeladen und gespeichert: flags/persia1933-civil.png
# Bild heruntergeladen und gespeichert: flags/qatar1933.png
# Bild heruntergeladen und gespeichert: flags/germany1933.png
# Bild heruntergeladen und gespeichert: flags/terengganu1933.png
# Bild heruntergeladen und gespeichert: flags/eastturkestan1933.png
# Bild heruntergeladen und gespeichert: flags/austria1934-state.png
# Bild heruntergeladen und gespeichert: flags/mexico1934.png
# Bild heruntergeladen und gespeichert: flags/costarica1934.png
# Bild heruntergeladen und gespeichert: flags/costarica1934-state.png
# Bild heruntergeladen und gespeichert: flags/bundi1935.png
# Bild heruntergeladen und gespeichert: flags/tannutuva1935.png
# Bild heruntergeladen und gespeichert: flags/burma1935.png
# Bild heruntergeladen und gespeichert: flags/karen1935.png
# Bild heruntergeladen und gespeichert: flags/qatar1936.png
# Bild heruntergeladen und gespeichert: flags/spain1928-civil.png
# Bild heruntergeladen und gespeichert: flags/kashmir1936.png
# Bild heruntergeladen und gespeichert: flags/baroda1936.png
# Bild heruntergeladen und gespeichert: flags/patiala1936.png
# Bild heruntergeladen und gespeichert: flags/philippines1936.png
# Bild heruntergeladen und gespeichert: flags/morocco1937.png
# Bild heruntergeladen und gespeichert: flags/liechtenstein1937.png
# Bild heruntergeladen und gespeichert: flags/hatay1938.png
# Bild heruntergeladen und gespeichert: flags/saudiarabia1938.png
# Bild heruntergeladen und gespeichert: flags/spain1938.png
# Bild heruntergeladen und gespeichert: flags/buganda1939.png
# Bild heruntergeladen und gespeichert: flags/jordan1939.png
# Bild heruntergeladen und gespeichert: flags/quaiti1939.png
# Bild heruntergeladen und gespeichert: flags/andorra1939.png
# Bild heruntergeladen und gespeichert: flags/croatia1939.png
# Bild heruntergeladen und gespeichert: flags/albania1939.png
# Bild heruntergeladen und gespeichert: flags/albania1939-state.png
# Bild heruntergeladen und gespeichert: flags/ratlam1940.png
# Bild heruntergeladen und gespeichert: flags/pudukkottai1940.png
# Bild heruntergeladen und gespeichert: flags/mongolia1940.png
# Fehler beim Herunterladen des Bildes https://flaglog.com/img/france1940-free.png: 404 Client Error: Not Found for url: https://flaglog.com/img/france1940-free.png
# Bild heruntergeladen und gespeichert: flags/tannutuva1941.png
# Bild heruntergeladen und gespeichert: flags/tohonooodham1941.png
# Bild heruntergeladen und gespeichert: flags/garifuna1941.png
# Fehler beim Herunterladen des Bildes https://flaglog.com/img/france1940-free.png: 404 Client Error: Not Found for url: https://flaglog.com/img/france1940-free.png
# Bild heruntergeladen und gespeichert: flags/korea1942.png
# Bild heruntergeladen und gespeichert: flags/lebanon1943.png
# Fehler beim Herunterladen des Bildes https://flaglog.com/img/france1940-free.png: 404 Client Error: Not Found for url: https://flaglog.com/img/france1940-free.png
# Bild heruntergeladen und gespeichert: flags/malta1943-civil.png
# Bild heruntergeladen und gespeichert: flags/yugoslavia1943.png
# Bild heruntergeladen und gespeichert: flags/bharatpur1943.png
# Bild heruntergeladen und gespeichert: flags/tannutuva1943.png
# Bild heruntergeladen und gespeichert: flags/burma1943-resistance.png
# Bild heruntergeladen und gespeichert: flags/austria1945-state.png
# Bild heruntergeladen und gespeichert: flags/spain1945.png
# Bild heruntergeladen und gespeichert: flags/germany1945.png
# Bild heruntergeladen und gespeichert: flags/janjira1945.png
# Bild heruntergeladen und gespeichert: flags/bahawalpur1945.png
# Bild heruntergeladen und gespeichert: flags/vietnam1945.png
# Bild heruntergeladen und gespeichert: flags/mongolia1945.png
# Bild heruntergeladen und gespeichert: flags/laos1945.png
# Bild heruntergeladen und gespeichert: flags/italy1946.png
# Bild heruntergeladen und gespeichert: flags/albania1946.png
# Bild heruntergeladen und gespeichert: flags/yugoslavia1946.png
# Bild heruntergeladen und gespeichert: flags/hungary1946.png
# Bild heruntergeladen und gespeichert: flags/sarawak1946.png
# Bild heruntergeladen und gespeichert: flags/saar1947.png
# Bild heruntergeladen und gespeichert: flags/trieste1947.png
# Bild heruntergeladen und gespeichert: flags/bulgaria1947.png
# Bild heruntergeladen und gespeichert: flags/india1947.png
# Bild heruntergeladen und gespeichert: flags/pakistan1947.png
# Bild heruntergeladen und gespeichert: flags/kashmir1947.png
# Bild heruntergeladen und gespeichert: flags/burma1947.png
# Bild heruntergeladen und gespeichert: flags/laos1947.png
# Bild heruntergeladen und gespeichert: flags/shan1947.png
# Bild heruntergeladen und gespeichert: flags/bulgaria1948.png
# Bild heruntergeladen und gespeichert: flags/romania1948.png
# Bild heruntergeladen und gespeichert: flags/ceylon1948.png
# Bild heruntergeladen und gespeichert: flags/northkorea1948.png
# Bild heruntergeladen und gespeichert: flags/southvietnam1948.png
# Bild heruntergeladen und gespeichert: flags/cambodia1948.png
# Bild heruntergeladen und gespeichert: flags/westernsamoa1948.png
# Bild heruntergeladen und gespeichert: flags/guam1948.png
# Bild heruntergeladen und gespeichert: flags/quebec1948.png
# Bild heruntergeladen und gespeichert: flags/goldcoast1949.png
# Bild heruntergeladen und gespeichert: flags/cyrenaica1949.png
# Bild heruntergeladen und gespeichert: flags/qatar1949.png
# Bild heruntergeladen und gespeichert: flags/germany1949.png
# Bild heruntergeladen und gespeichert: flags/hungary1949.png
# Bild heruntergeladen und gespeichert: flags/bhutan1949.png
# Bild heruntergeladen und gespeichert: flags/southkorea1949.png
# Bild heruntergeladen und gespeichert: flags/china1949.png
# Bild heruntergeladen und gespeichert: flags/taiwan1949.png
# Bild heruntergeladen und gespeichert: flags/samoa1949.png
# Bild heruntergeladen und gespeichert: flags/honduras1949.png
# Bild heruntergeladen und gespeichert: flags/bahrain1950.png
# Bild heruntergeladen und gespeichert: flags/cambodia1950-issarak.png
# Bild heruntergeladen und gespeichert: flags/malaya1950.png
# Bild heruntergeladen und gespeichert: flags/belize1950.png
# Bild heruntergeladen und gespeichert: flags/peru1950-state.png
# Bild heruntergeladen und gespeichert: flags/kenya1951.png
# Bild heruntergeladen und gespeichert: flags/libya1951.png
# Bild heruntergeladen und gespeichert: flags/ceylon1951.png
# Bild heruntergeladen und gespeichert: flags/eritrea1952.png
# Bild heruntergeladen und gespeichert: flags/fujairah1952.png
# Bild heruntergeladen und gespeichert: flags/romania1952.png
# Bild heruntergeladen und gespeichert: flags/kashmir1952.png
# Bild heruntergeladen und gespeichert: flags/uruguay1952-artigas.png
# Bild heruntergeladen und gespeichert: flags/uruguay1952-treinta.png
# Bild heruntergeladen und gespeichert: flags/nyasaland1953.png
# Bild heruntergeladen und gespeichert: flags/egypt1953.png
# Bild heruntergeladen und gespeichert: flags/aland1953.png
# Bild heruntergeladen und gespeichert: flags/northernireland1953.png
# Bild heruntergeladen und gespeichert: flags/wales1953.png
# Bild heruntergeladen und gespeichert: flags/tanganyika1954.png
# Bild heruntergeladen und gespeichert: flags/somalia1954.png
# Bild heruntergeladen und gespeichert: flags/eswatini1954.png
# Bild heruntergeladen und gespeichert: flags/venezuela1954-state.png
# Bild heruntergeladen und gespeichert: flags/kathiri1955.png
# Bild heruntergeladen und gespeichert: flags/ussr1955.png
# Bild heruntergeladen und gespeichert: flags/poland1955-state.png
# Bild heruntergeladen und gespeichert: flags/sudan1956.png
# Bild heruntergeladen und gespeichert: flags/bhutan1956.png
# Bild heruntergeladen und gespeichert: flags/nagaland1956.png
# Bild heruntergeladen und gespeichert: flags/arapaho1956.png
# Bild heruntergeladen und gespeichert: flags/ghana1957.png
# Bild heruntergeladen und gespeichert: flags/cameroon1957.png
# Bild heruntergeladen und gespeichert: flags/togo1957.png
# Bild heruntergeladen und gespeichert: flags/hungary1957.png
# Bild heruntergeladen und gespeichert: flags/canada1957.png
# Bild heruntergeladen und gespeichert: flags/paraguay1957.png
# Bild heruntergeladen und gespeichert: flags/paraguay1957-reverse.png
# Bild heruntergeladen und gespeichert: flags/guinea1958.png
# Bild heruntergeladen und gespeichert: flags/madagascar1958.png
# Bild heruntergeladen und gespeichert: flags/car1958.png
# Bild heruntergeladen und gespeichert: flags/togo1958.png
# Bild heruntergeladen und gespeichert: flags/senegal1958.png
# Bild heruntergeladen und gespeichert: flags/sudanese1958.png
# Bild heruntergeladen und gespeichert: flags/uar1958.png
# Bild heruntergeladen und gespeichert: flags/abudhabi1958.png
# Bild heruntergeladen und gespeichert: flags/westindies1958.png
# Bild heruntergeladen und gespeichert: flags/mali1959.png
# Bild heruntergeladen und gespeichert: flags/chad1959.png
# Bild heruntergeladen und gespeichert: flags/nigeria1959.png
# Bild heruntergeladen und gespeichert: flags/cotedivoire1959.png
# Bild heruntergeladen und gespeichert: flags/niger1959.png
# Bild heruntergeladen und gespeichert: flags/uppervolta1959.png
# Bild heruntergeladen und gespeichert: flags/congobrazzaville1959.png
# Bild heruntergeladen und gespeichert: flags/benin1959.png
# Bild heruntergeladen und gespeichert: flags/zambia1959.png
# Bild heruntergeladen und gespeichert: flags/gabon1959.png
# Bild heruntergeladen und gespeichert: flags/tunisia1959.png
# Bild heruntergeladen und gespeichert: flags/mauritania1959.png
# Bild heruntergeladen und gespeichert: flags/iraq1959.png
# Bild heruntergeladen und gespeichert: flags/southarabia1959.png
# Bild heruntergeladen und gespeichert: flags/eastgermany1959.png
# Bild heruntergeladen und gespeichert: flags/wales1959.png
# Bild heruntergeladen und gespeichert: flags/singapore1959.png
# Bild heruntergeladen und gespeichert: flags/brunei1959.png
# Bild heruntergeladen und gespeichert: flags/unitedstates1959.png
# Bild heruntergeladen und gespeichert: flags/suriname1959.png
# Bild heruntergeladen und gespeichert: flags/netherlandsantilles1959.png
# Bild heruntergeladen und gespeichert: flags/senegal1960.png
# Bild heruntergeladen und gespeichert: flags/gabon1960.png
# Bild heruntergeladen und gespeichert: flags/namibia1960.png
# Bild heruntergeladen und gespeichert: flags/togo1960.png
# Bild heruntergeladen und gespeichert: flags/congoleopoldville1960.png
# Bild heruntergeladen und gespeichert: flags/cyprus1960a.png
# Bild heruntergeladen und gespeichert: flags/americansamoa1960.png
# Bild heruntergeladen und gespeichert: flags/unitedstates1960.png
# Bild heruntergeladen und gespeichert: flags/brazil1960.png
# Bild heruntergeladen und gespeichert: flags/rwanda1961a.png
# Bild heruntergeladen und gespeichert: flags/mali1961.png
# Bild heruntergeladen und gespeichert: flags/cameroon1961.png
# Bild heruntergeladen und gespeichert: flags/sierraleone1961.png
# Bild heruntergeladen und gespeichert: flags/guineabissau1961.png
# Bild heruntergeladen und gespeichert: flags/tanganyika1961.png
# Bild heruntergeladen und gespeichert: flags/mozambique1961.png
# Bild heruntergeladen und gespeichert: flags/zimbabwe1961-zapu.png
# Bild heruntergeladen und gespeichert: flags/kuwait1961.png
# Bild heruntergeladen und gespeichert: flags/fujairah1961.png
# Bild heruntergeladen und gespeichert: flags/uaq1961.png
# Bild heruntergeladen und gespeichert: flags/mahra1961.png
# Bild heruntergeladen und gespeichert: flags/canaryislands1961.png
# Bild heruntergeladen und gespeichert: flags/westpapua1961.png
# Bild heruntergeladen und gespeichert: flags/mozambique1962.png
# Bild heruntergeladen und gespeichert: flags/angola1961-fnla.png
# Bild heruntergeladen und gespeichert: flags/uganda1962a.png
# Bild heruntergeladen und gespeichert: flags/burundi1962.png
# Bild heruntergeladen und gespeichert: flags/northyemen1962.png
# Bild heruntergeladen und gespeichert: flags/nepal1962.png
# Bild heruntergeladen und gespeichert: flags/papuanewguinea1962.png
# Bild heruntergeladen und gespeichert: flags/lakota1962.png
# Bild heruntergeladen und gespeichert: flags/jamaica1962.png
# Bild heruntergeladen und gespeichert: flags/trinidad1962.png
# Bild heruntergeladen und gespeichert: flags/kenya1963.png
# Bild heruntergeladen und gespeichert: flags/zimbabwe1963-zanu.png
# Bild heruntergeladen und gespeichert: flags/zanzibar1963.png
# Bild heruntergeladen und gespeichert: flags/congoleopoldville1963.png
# Bild heruntergeladen und gespeichert: flags/algeria1962.png
# Bild heruntergeladen und gespeichert: flags/iraq1963.png
# Bild heruntergeladen und gespeichert: flags/syria1963.png
# Bild heruntergeladen und gespeichert: flags/southarabia1963-nlf.png
# Bild heruntergeladen und gespeichert: flags/comoros1963.png
# Bild heruntergeladen und gespeichert: flags/malaysia1963.png
# Bild heruntergeladen und gespeichert: flags/northborneo1963.png
# Bild heruntergeladen und gespeichert: flags/ghana1964.png
# Bild heruntergeladen und gespeichert: flags/malawi1964.png
# Bild heruntergeladen und gespeichert: flags/tanzania1964.png
# Bild heruntergeladen und gespeichert: flags/angola1961-mpla.png
# Bild heruntergeladen und gespeichert: flags/zambia1964.png
# Bild heruntergeladen und gespeichert: flags/palestine1964.png
# Bild heruntergeladen und gespeichert: flags/iran1964.png
# Bild heruntergeladen und gespeichert: flags/iran1964-civil.png
# Bild heruntergeladen und gespeichert: flags/malta1964.png
# Bild heruntergeladen und gespeichert: flags/northerncheyenne1964.png
# Bild heruntergeladen und gespeichert: flags/costarica1964-state.png
# Bild heruntergeladen und gespeichert: flags/haiti1964.png
# Bild heruntergeladen und gespeichert: flags/gambia1965.png
# Bild heruntergeladen und gespeichert: flags/romania1965.png
# Bild heruntergeladen und gespeichert: flags/maldives1965.png
# Bild heruntergeladen und gespeichert: flags/kannada1965.png
# Bild heruntergeladen und gespeichert: flags/micronesia1965.png
# Bild heruntergeladen und gespeichert: flags/canada1965.png
# Bild heruntergeladen und gespeichert: flags/angola1966-unita.png
# Bild heruntergeladen und gespeichert: flags/burundi1966.png
# Bild heruntergeladen und gespeichert: flags/botswana1966.png
# Bild heruntergeladen und gespeichert: flags/lesotho1966.png
# Bild heruntergeladen und gespeichert: flags/congokinshasa1966.png
# Bild heruntergeladen und gespeichert: flags/gibraltar1966.png
# Bild heruntergeladen und gespeichert: flags/seminole1966.png
# Bild heruntergeladen und gespeichert: flags/guyana1966.png
# Bild heruntergeladen und gespeichert: flags/barbados1966.png
# Bild heruntergeladen und gespeichert: flags/burundi1967.png
# Bild heruntergeladen und gespeichert: flags/southyemen1967.png
# Bild heruntergeladen und gespeichert: flags/sikkim1967.png
# Bild heruntergeladen und gespeichert: flags/bermuda1967.png
# Bild heruntergeladen und gespeichert: flags/antigua1967.png
# Bild heruntergeladen und gespeichert: flags/frenchguiana1967.png
# Bild heruntergeladen und gespeichert: flags/saintlucia1967.png
# Bild heruntergeladen und gespeichert: flags/saintkitts1967a.png
# Bild heruntergeladen und gespeichert: flags/grenada1967.png
# Bild heruntergeladen und gespeichert: flags/anguilla1967.png
# Bild heruntergeladen und gespeichert: flags/dominica1967.png
# Bild heruntergeladen und gespeichert: flags/paraguay1967.png
# Bild heruntergeladen und gespeichert: flags/paraguay1967-reverse.png
# Bild heruntergeladen und gespeichert: flags/equatorialguinea1968.png
# Bild heruntergeladen und gespeichert: flags/assyria1968.png
# Bild heruntergeladen und gespeichert: flags/isleofman1968.png
# Bild heruntergeladen und gespeichert: flags/mauritius1968.png
# Bild heruntergeladen und gespeichert: flags/nauru1968.png
# Bild heruntergeladen und gespeichert: flags/cherokee1968.png
# Bild heruntergeladen und gespeichert: flags/navajo1968.png
# Bild heruntergeladen und gespeichert: flags/martinique1968.png
# Bild heruntergeladen und gespeichert: flags/brazil1968.png
# Bild heruntergeladen und gespeichert: flags/mexico1968.png
# Bild heruntergeladen und gespeichert: flags/libya1969.png
# Bild heruntergeladen und gespeichert: flags/bhutan1969.png
# Bild heruntergeladen und gespeichert: flags/southvietnam1969-prg.png
# Bild heruntergeladen und gespeichert: flags/saintvincent1962.png
# Bild heruntergeladen und gespeichert: flags/congobrazzaville1970.png
# Bild heruntergeladen und gespeichert: flags/sudan1970.png
# Bild heruntergeladen und gespeichert: flags/oman1970.png
# Bild heruntergeladen und gespeichert: flags/greece1970.png
# Bild heruntergeladen und gespeichert: flags/khmer1970.png
# Bild heruntergeladen und gespeichert: flags/fiji1970.png
# Bild heruntergeladen und gespeichert: flags/wiphala1970.png
# Bild heruntergeladen und gespeichert: flags/zaire1971.png
# Bild heruntergeladen und gespeichert: flags/uae1971.png
# Bild heruntergeladen und gespeichert: flags/andorra1971.png
# Bild heruntergeladen und gespeichert: flags/bulgaria1971.png
# Bild heruntergeladen und gespeichert: flags/bangladesh1971.png
# Bild heruntergeladen und gespeichert: flags/papuanewguinea1971.png
# Bild heruntergeladen und gespeichert: flags/australia1971-aboriginal.png
# Bild heruntergeladen und gespeichert: flags/nicaragua1971.png
# Bild heruntergeladen und gespeichert: flags/quechua1971.png
# Bild heruntergeladen und gespeichert: flags/saotome1972.png
# Bild heruntergeladen und gespeichert: flags/djibouti1972.png
# Bild heruntergeladen und gespeichert: flags/far1972.png
# Bild heruntergeladen und gespeichert: flags/bangladesh1972.png
# Bild heruntergeladen und gespeichert: flags/srilanka1972.png
# Bild heruntergeladen und gespeichert: flags/cnmi1972.png
# Bild heruntergeladen und gespeichert: flags/equatorialguinea1973.png
# Bild heruntergeladen und gespeichert: flags/oromia1973.png
# Bild heruntergeladen und gespeichert: flags/westernsahara1973.png
# Bild heruntergeladen und gespeichert: flags/saudiarabia1973.png
# Bild heruntergeladen und gespeichert: flags/flanders1973.png
# Bild heruntergeladen und gespeichert: flags/afghanistan1973.png
# Bild heruntergeladen und gespeichert: flags/sarawak1973.png
# Bild heruntergeladen und gespeichert: flags/ainu1973.png
# Bild heruntergeladen und gespeichert: flags/cookislands1973.png
# Bild heruntergeladen und gespeichert: flags/bahamas1973.png
# Bild heruntergeladen und gespeichert: flags/afghanistan1974.png
# Bild heruntergeladen und gespeichert: flags/easttimor1974.png
# Bild heruntergeladen und gespeichert: flags/burma1974.png
# Bild heruntergeladen und gespeichert: flags/grenada1974.png
# Bild heruntergeladen und gespeichert: flags/ethiopia1975a-state.png
# Bild heruntergeladen und gespeichert: flags/cameroon1975.png
# Bild heruntergeladen und gespeichert: flags/capeverde1975.png
# Bild heruntergeladen und gespeichert: flags/angola1975.png
# Bild heruntergeladen und gespeichert: flags/mozambique1975.png
# Bild heruntergeladen und gespeichert: flags/benin1975.png
# Bild heruntergeladen und gespeichert: flags/saotome1975.png
# Bild heruntergeladen und gespeichert: flags/tigray1975.png
# Bild heruntergeladen und gespeichert: flags/comoros1975.png
# Bild heruntergeladen und gespeichert: flags/kampuchea1975-red.png
# Bild heruntergeladen und gespeichert: flags/timorleste1975.png
# Bild heruntergeladen und gespeichert: flags/niue1975.png
# Bild heruntergeladen und gespeichert: flags/frenchpolynesia1975.png
# Bild heruntergeladen und gespeichert: flags/bougainville1975.png
# Bild heruntergeladen und gespeichert: flags/suriname1975.png
# Bild heruntergeladen und gespeichert: flags/seychelles1976.png
# ...
# Bild heruntergeladen und gespeichert: flags/spain1977.png
# Bild heruntergeladen und gespeichert: flags/sapmi1977.png
# Bild heruntergeladen und gespeichert: flags/seychelles1977.png
# Bild heruntergeladen und gespeichert: flags/solomon1977.png
# Bild heruntergeladen und gespeichert: flags/vanuaaku1977.png
# Bild heruntergeladen und gespeichert: flags/finland1978-state.png
# Bild heruntergeladen und gespeichert: flags/madeira1978.png
# Bild heruntergeladen und gespeichert: flags/afghanistan1978a.png
# Bild heruntergeladen und gespeichert: flags/comoros1978.png
# Bild heruntergeladen und gespeichert: flags/tuvalu1978.png
# Bild heruntergeladen und gespeichert: flags/micronesia1978.png
# Bild heruntergeladen und gespeichert: flags/cherokee1978.png
# Bild heruntergeladen und gespeichert: flags/dominica1978.png
# Bild heruntergeladen und gespeichert: flags/azores1979.png
# Bild heruntergeladen und gespeichert: flags/cookislands1979.png
# Bild heruntergeladen und gespeichert: flags/marshallislands1979.png
# Bild heruntergeladen und gespeichert: flags/kiribati1979.png
# Bild heruntergeladen und gespeichert: flags/norfolk1979.png
# Bild heruntergeladen und gespeichert: flags/choctaw1979.png
# Bild heruntergeladen und gespeichert: flags/saintlucia1979.png
# Bild heruntergeladen und gespeichert: flags/saintvincent1979.png
# Bild heruntergeladen und gespeichert: flags/zimbabwe1980.png
# Bild heruntergeladen und gespeichert: flags/syria1980.png
# Bild heruntergeladen und gespeichert: flags/iran1980.png
# Bild heruntergeladen und gespeichert: flags/afghanistan1980.png
# Bild heruntergeladen und gespeichert: flags/vanuatu1980.png
# Bild heruntergeladen und gespeichert: flags/palau1980.png
# Bild heruntergeladen und gespeichert: flags/newfoundland1980.png
# Bild heruntergeladen und gespeichert: flags/blackfeet1980.png
# Bild heruntergeladen und gespeichert: flags/misak1980.png
# Bild heruntergeladen und gespeichert: flags/spain1981.png
# Bild heruntergeladen und gespeichert: flags/jersey1981.png
# Bild heruntergeladen und gespeichert: flags/cnmi1981.png
# Bild heruntergeladen und gespeichert: flags/dominica1981.png
# Bild heruntergeladen und gespeichert: flags/bonaire1981.png
# Bild heruntergeladen und gespeichert: flags/belize1981.png
# Bild heruntergeladen und gespeichert: flags/burundi1982.png
# Bild heruntergeladen und gespeichert: flags/liechtenstein1982.png
# Bild heruntergeladen und gespeichert: flags/canaryislands1982.png
# Bild heruntergeladen und gespeichert: flags/mayotte1982.png
# Bild heruntergeladen und gespeichert: flags/balochistan1982.png
# Bild heruntergeladen und gespeichert: flags/sabah1982.png
# Bild heruntergeladen und gespeichert: flags/rapanui1982.png
# Bild heruntergeladen und gespeichert: flags/saintpierre1982.png
# Bild heruntergeladen und gespeichert: flags/mozambique1983.png
# Bild heruntergeladen und gespeichert: flags/southsudan1983.png
# Bild heruntergeladen und gespeichert: flags/chagos1983.png
# Bild heruntergeladen und gespeichert: flags/saintkitts1983.png
# Bild heruntergeladen und gespeichert: flags/burkinafaso1984.png
# Bild heruntergeladen und gespeichert: flags/egypt1984.png
# Bild heruntergeladen und gespeichert: flags/northerncyprus1984.png
# Bild heruntergeladen und gespeichert: flags/saudiarabia1984.png
# Bild heruntergeladen und gespeichert: flags/galicia1984.png
# Bild heruntergeladen und gespeichert: flags/newcaledonia1984.png
# Bild heruntergeladen und gespeichert: flags/frenchpolynesia1984.png
# Bild heruntergeladen und gespeichert: flags/guadeloupe1984.png
# Bild heruntergeladen und gespeichert: flags/curacao1984.png
# Bild heruntergeladen und gespeichert: flags/guernsey1985.png
# Bild heruntergeladen und gespeichert: flags/philippines1985.png
# Bild heruntergeladen und gespeichert: flags/greenland1985.png
# Bild heruntergeladen und gespeichert: flags/saintvincent1985.png
# Bild heruntergeladen und gespeichert: flags/sintmaarten1985.png
# Bild heruntergeladen und gespeichert: flags/saba1985.png
# Bild heruntergeladen und gespeichert: flags/sapmi1986.png
# Bild heruntergeladen und gespeichert: flags/rohingya1986.png
# Bild heruntergeladen und gespeichert: flags/christmasisland1986.png
# Bild heruntergeladen und gespeichert: flags/tohonooodham1986.png
# Bild heruntergeladen und gespeichert: flags/netherlandsantilles1986.png
# Bild heruntergeladen und gespeichert: flags/haiti1986.png
# Bild heruntergeladen und gespeichert: flags/ethiopia1987.png
# Bild heruntergeladen und gespeichert: flags/lesotho1987.png
# Bild heruntergeladen und gespeichert: flags/afghanistan1987.png
# Bild heruntergeladen und gespeichert: flags/lithuania1988.png
# Bild heruntergeladen und gespeichert: flags/afghanistan1988-interim.png
# Bild heruntergeladen und gespeichert: flags/sarawak1988.png
# Bild heruntergeladen und gespeichert: flags/sabah1988.png
# Bild heruntergeladen und gespeichert: flags/dominica1988.png
# Bild heruntergeladen und gespeichert: flags/afghanistan1989-interim.png
# Bild heruntergeladen und gespeichert: flags/cambodia1989.png
# Bild heruntergeladen und gespeichert: flags/cherokee1989.png
# Bild heruntergeladen und gespeichert: flags/haida1989.png
# Bild heruntergeladen und gespeichert: flags/namibia1990.png
# Bild heruntergeladen und gespeichert: flags/yemen1990.png
# Bild heruntergeladen und gespeichert: flags/croatia1990.png
# Bild heruntergeladen und gespeichert: flags/bulgaria1990.png
# Bild heruntergeladen und gespeichert: flags/armenia1990.png
# Bild heruntergeladen und gespeichert: flags/azerbaijan1990.png
# Bild heruntergeladen und gespeichert: flags/georgia1990.png
# Bild heruntergeladen und gespeichert: flags/moldova1990.png
# Bild heruntergeladen und gespeichert: flags/ossetia1990.png
# Bild heruntergeladen und gespeichert: flags/chechnya1990.png
# Bild heruntergeladen und gespeichert: flags/gagauzia1990.png
# Bild heruntergeladen und gespeichert: flags/maori1990.png
# Bild heruntergeladen und gespeichert: flags/haudenosaunee1990.png
# Bild heruntergeladen und gespeichert: flags/dominica1990.png
# Bild heruntergeladen und gespeichert: flags/saintmartin2022-unity.png
# Bild heruntergeladen und gespeichert: flags/ethiopia1991.png
# Bild heruntergeladen und gespeichert: flags/somaliland1991.png
# Bild heruntergeladen und gespeichert: flags/iraq1991.png
# Bild heruntergeladen und gespeichert: flags/russia1991.png
# Bild heruntergeladen und gespeichert: flags/slovenia1991.png
# Bild heruntergeladen und gespeichert: flags/belarus1991.png
# Bild heruntergeladen und gespeichert: flags/macedonia1991.png
# Bild heruntergeladen und gespeichert: flags/chechnya1991.png
# Bild heruntergeladen und gespeichert: flags/tatarstan1991.png
# Bild heruntergeladen und gespeichert: flags/crimeantatar1991.png
# Bild heruntergeladen und gespeichert: flags/kazakhstan1953.png
# Bild heruntergeladen und gespeichert: flags/turkmenistan1953.png
# Bild heruntergeladen und gespeichert: flags/kyrgyzstan1952.png
# Bild heruntergeladen und gespeichert: flags/tajikistan1953.png
# Bild heruntergeladen und gespeichert: flags/uzbekistan1991.png
# Bild heruntergeladen und gespeichert: flags/comanche1991.png
# Bild heruntergeladen und gespeichert: flags/caboverde1992.png
# Bild heruntergeladen und gespeichert: flags/yugoslavia1992.png
# Bild heruntergeladen und gespeichert: flags/albania1992.png
# Bild heruntergeladen und gespeichert: flags/macedonia1992.png
# Bild heruntergeladen und gespeichert: flags/bosnia1992a.png
# Bild heruntergeladen und gespeichert: flags/adygea1992.png
# Bild heruntergeladen und gespeichert: flags/abkhazia1992.png
# Bild heruntergeladen und gespeichert: flags/chuvashia1992.png
# Bild heruntergeladen und gespeichert: flags/kalmykia1992.png
# Bild heruntergeladen und gespeichert: flags/mariel1992.png
# Bild heruntergeladen und gespeichert: flags/bashkortostan1992.png
# Bild heruntergeladen und gespeichert: flags/afghanistan1992a.png
# Bild heruntergeladen und gespeichert: flags/afghanistan1992-north.png
# Bild heruntergeladen und gespeichert: flags/tajikistan1992.png
# Bild heruntergeladen und gespeichert: flags/kyrgyzstan1992.png
# Bild heruntergeladen und gespeichert: flags/kazakhstan1992.png
# Bild heruntergeladen und gespeichert: flags/turkmenistan1992.png
# Bild heruntergeladen und gespeichert: flags/karakalpakstan1992.png
# Bild heruntergeladen und gespeichert: flags/mongolia1992.png
# Bild heruntergeladen und gespeichert: flags/buryatia1992.png
# Bild heruntergeladen und gespeichert: flags/tuva1992.png
# Bild heruntergeladen und gespeichert: flags/sakha1992.png
# Bild heruntergeladen und gespeichert: flags/altai1992.png
# Bild heruntergeladen und gespeichert: flags/comoros1992.png
# Bild heruntergeladen und gespeichert: flags/cambodia1992.png
# Bild heruntergeladen und gespeichert: flags/armm1992.png
# Bild heruntergeladen und gespeichert: flags/australia1992-torres.png
# Bild heruntergeladen und gespeichert: flags/hochunk1992.png
# Bild heruntergeladen und gespeichert: flags/brazil1992.png
# Bild heruntergeladen und gespeichert: flags/paraguay1992.png
# Bild heruntergeladen und gespeichert: flags/paraguay1992-reverse.png
# Bild heruntergeladen und gespeichert: flags/mapuche1992.png
# Bild heruntergeladen und gespeichert: flags/eritrea1993.png
# Bild heruntergeladen und gespeichert: flags/ogoni1993.png
# Bild heruntergeladen und gespeichert: flags/slovakia1993.png
# Bild heruntergeladen und gespeichert: flags/czechia1993.png
# Bild heruntergeladen und gespeichert: flags/udmurtia1992.png
# Bild heruntergeladen und gespeichert: flags/gagauzia1993.png
# Bild heruntergeladen und gespeichert: flags/karelia1993.png
# Bild heruntergeladen und gespeichert: flags/kalmykia1993.png
# Bild heruntergeladen und gespeichert: flags/anishinabek1993.png
# Bild heruntergeladen und gespeichert: flags/seminole1993.png
# Bild heruntergeladen und gespeichert: flags/southafrica1994.png
# Bild heruntergeladen und gespeichert: flags/komi1994.png
# Bild heruntergeladen und gespeichert: flags/altai1994.png
# Bild heruntergeladen und gespeichert: flags/southseaislander1994.png
# Bild heruntergeladen und gespeichert: flags/eritrea1995.png
# Bild heruntergeladen und gespeichert: flags/southsudan1995.png
# Bild heruntergeladen und gespeichert: flags/oman1995.png
# Bild heruntergeladen und gespeichert: flags/macedonia1995.png
# Bild heruntergeladen und gespeichert: flags/belarus1995.png
# Bild heruntergeladen und gespeichert: flags/gagauzia1995.png
# Bild heruntergeladen und gespeichert: flags/tuvalu1995a.png
# Bild heruntergeladen und gespeichert: flags/cnmi1995.png
# Bild heruntergeladen und gespeichert: flags/ethiopia1996a.png
# Bild heruntergeladen und gespeichert: flags/somaliland1996.png
# Bild heruntergeladen und gespeichert: flags/afghanistan1996-taliban.png
# Bild heruntergeladen und gespeichert: flags/jao1996.png
# Bild heruntergeladen und gespeichert: flags/comoros1996.png
# Bild heruntergeladen und gespeichert: flags/seychelles1996.png
# Bild heruntergeladen und gespeichert: flags/reunion1996.png
# Bild heruntergeladen und gespeichert: flags/congokinshasa1997.png
# Bild heruntergeladen und gespeichert: flags/amazigh1997.png
# Bild heruntergeladen und gespeichert: flags/komi1997.png
# Bild heruntergeladen und gespeichert: flags/afghanistan1997-taliban.png
# Bild heruntergeladen und gespeichert: flags/turkmenistan1997.png
# Bild heruntergeladen und gespeichert: flags/hongkong1990.png
# Bild heruntergeladen und gespeichert: flags/barbuda1997.png
# Bild heruntergeladen und gespeichert: flags/bosnia1998.png
# Bild heruntergeladen und gespeichert: flags/costarica1998-state.png
# Bild heruntergeladen und gespeichert: flags/maya1998.png
# Bild heruntergeladen und gespeichert: flags/tunisia1999.png
# Bild heruntergeladen und gespeichert: flags/japan1999.png
# Bild heruntergeladen und gespeichert: flags/macau1993.png
# Bild heruntergeladen und gespeichert: flags/pitcairn1999.png
# Bild heruntergeladen und gespeichert: flags/bermuda1999.png
# Bild heruntergeladen und gespeichert: flags/nunavut1999.png
# Bild heruntergeladen und gespeichert: flags/bvi1999.png
# Bild heruntergeladen und gespeichert: flags/montserrat1999.png
# Bild heruntergeladen und gespeichert: flags/tci1999.png
# Bild heruntergeladen und gespeichert: flags/caymanislands1962.png
# Bild heruntergeladen und gespeichert: flags/falklandislands1999.png
# Bild heruntergeladen und gespeichert: flags/sainthelena1999.png
# Bild heruntergeladen und gespeichert: flags/anguilla1999.png
# Bild heruntergeladen und gespeichert: flags/sicily2000.png
# Bild heruntergeladen und gespeichert: flags/rwanda2001.png
# Bild heruntergeladen und gespeichert: flags/turkmenistan2001.png
# Bild heruntergeladen und gespeichert: flags/nisgaa2001.png
# Bild heruntergeladen und gespeichert: flags/taino2001.png
# Bild heruntergeladen und gespeichert: flags/bahrain2002.png
# Bild heruntergeladen und gespeichert: flags/afghanistan2002.png
# Bild heruntergeladen und gespeichert: flags/tuva2002.png
# Bild heruntergeladen und gespeichert: flags/comoros2002.png
# Bild heruntergeladen und gespeichert: flags/hopi2002.png
# Bild heruntergeladen und gespeichert: flags/tristandacunha2002.png
# Bild heruntergeladen und gespeichert: flags/bashkortostan2003.png
# Bild heruntergeladen und gespeichert: flags/reunion2003.png
# Bild heruntergeladen und gespeichert: flags/iraq2004.png
# Bild heruntergeladen und gespeichert: flags/serbia2004-state.png
# Bild heruntergeladen und gespeichert: flags/georgia2004.png
# Bild heruntergeladen und gespeichert: flags/lithuania2004.png
# Bild heruntergeladen und gespeichert: flags/lithuania2004-state.png
# Bild heruntergeladen und gespeichert: flags/montenegro2004.png
# Bild heruntergeladen und gespeichert: flags/chechnya2004.png
# Bild heruntergeladen und gespeichert: flags/szekely2004.png
# Bild heruntergeladen und gespeichert: flags/afghanistan2004.png
# Bild heruntergeladen und gespeichert: flags/cocos2004.png
# Bild heruntergeladen und gespeichert: flags/sinteustatius2004.png
# Bild heruntergeladen und gespeichert: flags/bolivia2004.png
# Bild heruntergeladen und gespeichert: flags/bolivia2004-civil.png
# Bild heruntergeladen und gespeichert: flags/guarani2004.png
# Bild heruntergeladen und gespeichert: flags/zanzibar2005.png
# Bild heruntergeladen und gespeichert: flags/tlicho2005.png
# Bild heruntergeladen und gespeichert: flags/lesotho2006.png
# Bild heruntergeladen und gespeichert: flags/congokinshasa2006.png
# Bild heruntergeladen und gespeichert: flags/palestine2006.png
# Bild heruntergeladen und gespeichert: flags/cyprus2006.png
# Bild heruntergeladen und gespeichert: flags/mariel2006.png
# Bild heruntergeladen und gespeichert: flags/venezuela2006-state.png
# Bild heruntergeladen und gespeichert: flags/venezuela2006.png
# Bild heruntergeladen und gespeichert: flags/saintmartin2007.png
# Bild heruntergeladen und gespeichert: flags/saintbarthelemy2007.png
# Bild heruntergeladen und gespeichert: flags/iraq2008.png
# Bild heruntergeladen und gespeichert: flags/kosovo2008.png
# Bild heruntergeladen und gespeichert: flags/tokelau2009.png
# Bild heruntergeladen und gespeichert: flags/ecuador2009.png
# Bild heruntergeladen und gespeichert: flags/malawi2010.png
# Bild heruntergeladen und gespeichert: flags/serbia2010-state.png
# Bild heruntergeladen und gespeichert: flags/myanmar2010.png
# Bild heruntergeladen und gespeichert: flags/saintmartin2010.png
# Bild heruntergeladen und gespeichert: flags/syria2011-opposition.png
# Bild heruntergeladen und gespeichert: flags/sanmarino2011.png
# Bild heruntergeladen und gespeichert: flags/mariel2011.png
# Bild heruntergeladen und gespeichert: flags/mayotte2011.png
# Bild heruntergeladen und gespeichert: flags/belarus2012.png
# Bild heruntergeladen und gespeichert: flags/tohonooodham2013.png
# Bild heruntergeladen und gespeichert: flags/paraguay2013.png
# Bild heruntergeladen und gespeichert: flags/paraguay2013-reverse.png
# Bild heruntergeladen und gespeichert: flags/mauritania2017.png
# Bild heruntergeladen und gespeichert: flags/bangsamoro2019.png
# Bild heruntergeladen und gespeichert: flags/martinique2019.png
# Bild heruntergeladen und gespeichert: flags/belize2019.png
# Bild heruntergeladen und gespeichert: flags/afghanistan2021-taliban.png
# Bild heruntergeladen und gespeichert: flags/honduras2022.png
# Bild heruntergeladen und gespeichert: flags/kyrgyzstan2023.png
# Alle Bilder wurden erfolgreich heruntergeladen und im Ordner 'flags' gespeichert.

# %%
import requests  # Library to make HTTP requests
from bs4 import BeautifulSoup  # Library to parse HTML and XML documents
import csv  # Library to handle CSV file operations
from PIL import Image  # Python Imaging Library to handle image processing
from io import BytesIO  # Library to handle byte streams
from collections import Counter  # Library to count hashable objects

# List to keep track of image URLs to avoid duplicates
image_urls = []
# Dictionary to store flags by year
flags1 = {}

# Function to download an image from a URL
def download_image(url):
    response = requests.get(url)  # Send a GET request to the URL
    response.raise_for_status()  # Raise an HTTPError for bad responses
    return Image.open(BytesIO(response.content))  # Open the image from the response content

# Function to map RGB colors to predefined color categories
def get_color_category(rgb_color):
    color_categories = {
        "green": (0, 128, 0),
        "turquoise": (0, 255, 255),  # previously "blue-green"
        "blue": (0, 0, 255),
        "violet": (128, 0, 128),
        "pink": (255, 0, 255),  # previously "red-violet"
        "red": (255, 69, 0),  # previously "red-orange"
        "orange": (255, 165, 0),
        "yellow": (255, 215, 0),  # previously "yellow-orange"
        "white": (255, 255, 255),  # new color
        "black": (0, 0, 0)  # new color
    }

    min_dist = float("inf")  # Initialize minimum distance
    closest_category = None  # Initialize closest category

    for category, color in color_categories.items():  # Iterate over predefined color categories
        dist = sum((comp1 - comp2) ** 2 for comp1, comp2 in zip(rgb_color, color))  # Calculate Euclidean distance
        if dist < min_dist:  # If the distance is smaller, update the closest category
            min_dist = dist
            closest_category = category

    return closest_category  # Return the closest color category

# Function to analyze the colors in an image
def analyze_image_colors(image):
    image = image.convert("RGB")  # Convert image to RGB mode
    pixels = list(image.getdata())  # Get all pixel data from the image
    color_counts = Counter(
        [
            get_color_category(pixel)  # Get color category for each pixel
            for pixel in pixels
            if get_color_category(pixel) is not None  # Ensure pixel maps to a category
        ]
    )

    # Calculate total number of pixels and percentage of each color
    total_pixels = sum(color_counts.values())
    color_percentages = {
        color: round((count / total_pixels) * 100, 2)  # Calculate percentage for each color
        for color, count in color_counts.items()
    }

    # Ensure all colors are represented in the output
    for color in [
        "green",
        "turquoise",
        "blue",
        "violet",
        "pink",
        "red",
        "orange",
        "yellow",
        "white",
        "black"
    ]:
        if color not in color_percentages:
            color_percentages[color] = 0

    return color_percentages  # Return dictionary of color percentages

# Create and write the header row to a CSV file
with open("flags1.csv", mode="w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow(
        [
            "Image URL",
            "Region",
            "State Name",
            "Flag Name",
            "Additional Info",
            "Year Added",
            "Year Removed",
            "green",
            "turquoise",
            "blue",
            "violet",
            "pink",
            "red",
            "orange",
            "yellow",
            "white",
            "black"
        ]
    )

# URL of the website to scrape data from
for year in range(1874, 2024):  # Loop through years from 1874 to 2023
    url = f"https://flaglog.com/{year}"  # Construct URL for the specific year
    flags1[year] = []  # Initialize list to store flags for the year

    response = requests.get(url)  # Send a GET request to the URL
    response.raise_for_status()  # Raise an HTTPError for bad responses

    soup = BeautifulSoup(response.content, "html.parser")  # Parse the HTML content

    for section in soup.find_all("section"):  # Loop through all sections in the HTML
        if section.get("id") != "Other":  # Skip sections with id "Other"
            region = section.get("id", "Unknown")  # Get region from section id
            for flag_div in section.find_all("div", class_="flag"):  # Loop through all flag divs
                image_url = "https://flaglog.com/" + flag_div.find("img")["src"]  # Construct image URL
                state_name_div = flag_div.find("div", class_="flagname")
                state_name = str(state_name_div).replace('<div class="flagname">', "")  # Extract state name
                state_name = state_name.split("<")[0]  # Further clean state name

                flag_name_div = flag_div.find("div", class_="type")
                flag_name = "N/A"  # Default flag name
                if flag_name_div:  # If flag name div is present
                    flag_name = flag_name_div.text.strip()  # Get flag name text
                    for i, char in enumerate(flag_name):  # Remove trailing digits
                        if char.isdigit():
                            flag_name = flag_name[:i].strip()
                            break

                comment_element = flag_div.find("span", class_="popnote")
                comment = comment_element.text.strip() if comment_element else "N/A"  # Get comment text
                comment = comment.replace("&nbsp;", "")  # Remove non-breaking spaces
                comment = "".join([i for i in comment if not i.isdigit()])  # Remove digits

                year_added = "".join([i for i in image_url if i.isdigit()])  # Extract year from image URL
                if len(year_added) != 4:
                    year_added = "?"  # Default to "?" if year format is incorrect

                if image_url not in image_urls:  # Check if the image URL is not already processed
                    try:
                        image = download_image(image_url)  # Download the image
                        color_percentages = analyze_image_colors(image)  # Analyze image colors
                    except Exception as e:
                        print(f"Fehler beim Verarbeiten des Bildes {image_url}: {e}")  # Print error message if any
                        color_percentages = {  # Default to 0 percentages for all colors
                            color: 0
                            for color in [
                                "green",
                                "turquoise",
                                "blue",
                                "violet",
                                "pink",
                                "red",
                                "orange",
                                "yellow",
                                "white",
                                "black"
                            ]
                        }

                    # Write flag information and color percentages to CSV file
                    with open("flags1.csv", mode="a", newline="", encoding="utf-8") as file:
                        writer = csv.writer(file)
                        writer.writerow(
                            [
                                image_url,
                                region,
                                state_name,
                                flag_name,
                                comment,
                                year_added,
                                "still in use",
                                color_percentages["green"],
                                color_percentages["turquoise"],
                                color_percentages["blue"],
                                color_percentages["violet"],
                                color_percentages["pink"],
                                color_percentages["red"],
                                color_percentages["orange"],
                                color_percentages["yellow"],
                                color_percentages["white"],
                                color_percentages["black"]
                            ]
                        )
                    image_urls.append(image_url)  # Add image URL to processed list
                flags1[year].append(image_url)  # Add image URL to the list for the year

    if year == 1874:  # Skip the year 1874 for removal checks
        continue

    # Identify flags removed in the current year
    rip_flags = [flag for flag in flags1[year - 1] if flag not in flags1[year]]
    updated_rows = []

    # Read existing rows from the CSV file
    with open("flags1.csv", mode="r", newline="", encoding="utf-8") as read_file:
        reader = csv.reader(read_file)
        existing_rows = list(reader)

    for row in existing_rows:  # Loop through existing rows
        if row[0] in rip_flags:  # If the flag URL is in the removal list
            row[6] = year  # Update the "Year Removed" field
        updated_rows.append(row)  # Add the row to updated rows

    # Write the updated rows back to the CSV file
    with open("flags1.csv", mode="w", newline="", encoding="utf-8") as write_file:
        writer = csv.writer(write_file)
        writer.writerows(updated_rows)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 147
#     145 try:
#     146     image = download_image(image_url)  # Download the image
# --> 147     color_percentages = analyze_image_colors(image)  # Analyze image colors
#     148 except Exception as e:
#     149     print(f"Fehler beim Verarbeiten des Bildes {image_url}: {e}")  # Print error message if any
#
# Cell In[3], line 50, in analyze_image_colors(image)
#      47 image = image.convert("RGB")  # Convert image to RGB mode
#      48 pixels = list(image.getdata())  # Get all pixel data from the image
#      49 color_counts = Counter(
# ---> 50     [
#      51         get_color_category(pixel)  # Get color category for each pixel
#      52         for pixel in pixels
#      53         if get_color_category(pixel) is not None  # Ensure pixel maps to a category
#      54     ]
#      55 )
#      57 # Calculate total number of pixels and percentage of each color
#      58 total_pixels = sum(color_counts.values())
#
# Cell In[3], line 53, in <listcomp>(.0)
#      47 image = image.convert("RGB")  # Convert image to RGB mode
#      48 pixels = list(image.getdata())  # Get all pixel data from the image
#      49 color_counts = Counter(
#      50     [
#      51         get_color_category(pixel)  # Get color category for each pixel
#      52         for pixel in pixels
# ---> 53         if get_color_category(pixel) is not None  # Ensure pixel maps to a category
#      54     ]
#      55 )
#      57 # Calculate total number of pixels and percentage of each color
#      58 total_pixels = sum(color_counts.values())
#
# Cell In[3], line 38, in get_color_category(rgb_color)
#      35 closest_category = None  # Initialize closest category
#      37 for category, color in color_categories.items():  # Iterate over predefined color categories
# ---> 38     dist = sum((comp1 - comp2) ** 2 for comp1, comp2 in zip(rgb_color, color))  # Calculate Euclidean distance
#      39     if dist < min_dist:  # If the distance is smaller, update the closest category
#      40         min_dist = dist
#
# KeyboardInterrupt:
